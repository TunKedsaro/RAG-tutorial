# %%
# !pip -q install langchain openai pinecone langchain-huggingface
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.6/587.6 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.3/259.3 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 3.1 MB/s eta 0:00:00

# %%
from datasets import load_dataset

# %%
from google.colab import userdata
pinecone_api = userdata.get('PINECONE_API_KEY')

# %%
from pinecone import ServerlessSpec

# %%
spec = ServerlessSpec(
    cloud  = "aws",
    region = "us-east-1"
)

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
# load embedding
embeddings  = HuggingFaceEmbeddings(model_name = "sentence-transformers/all-mpnet-base-v2")
embed_model = embeddings
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
embed = embed_model.embed_documents("ฝนตกหนักถล่มภาพเหนือ")
len(embed),len(embed[0])
# Out:
# (20, 768)

# %%
import time
from pinecone import Pinecone

# %%
pc = Pinecone(api_key = pinecone_api)
index_name = "us-place-thai-all-mpnet-base-v2"
existing_indexes = [index_info["name"] for index_info in pc.list_indexes()]
if index_name not in existing_indexes:
    pc.create_index(index_name,dimension = 768, metric = 'dotproduct', spec = spec)
    while not pc.describe_index(index_name).status['ready']:
        time.sleep(1)
    print(f"Create vector database name {index_name} successfull !")
else:
    print(f"Aready got vector database name {index_name} !!!")
# Out:
# Aready got vector database name us-place-thai-all-mpnet-base-v2 !!!

# %%
index = pc.Index(index_name)
time.sleep(1)
index.describe_index_stats()
# Out:
# {'dimension': 768,
#  'index_fullness': 0.0,
#  'metric': 'dotproduct',
#  'namespaces': {},
#  'total_vector_count': 0,
#  'vector_type': 'dense'}

# %%
from datasets import load_dataset

# %%
dataset = load_dataset(
    "Tun555/us-places-thai",
    split = "train"
)
data = dataset.to_pandas()
data["DESTINATION"] = data["DESTINATION_TH"]
data["NAME"] = data["NAME_TH"]
data["DESCRIPTION"] = data["DESCRIPTION_TH"]
data["REVIEWS"] = data["REVIEWS_TH"]
data = data[['RATING', 'PICTURE','URL', 'DESTINATION', 'NAME', 'DESCRIPTION', 'REVIEWS']]
data
# Out:
# README.md:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# train.csv: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/135 [00:00<?, ? examples/s]
#      RATING                                            PICTURE  \
# 0       4.5  https://dynamic-media-cdn.tripadvisor.com/medi...
# 1       4.5  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2       4.0                                               None
# 3       5.0  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4       4.5  https://dynamic-media-cdn.tripadvisor.com/medi...
# ..      ...                                                ...
# 130     4.5  https://dynamic-media-cdn.tripadvisor.com/medi...
# 131     5.0  https://dynamic-media-cdn.tripadvisor.com/medi...
# 132     4.0  https://dynamic-media-cdn.tripadvisor.com/medi...
# 133     5.0  https://dynamic-media-cdn.tripadvisor.com/medi...
# 134     4.5  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                    URL DESTINATION  \
# 0    https://www.tripadvisor.com/Attraction_Review-...      ออสติน
# 1    https://www.tripadvisor.com/Attraction_Review-...      ออสติน
# 2    https://www.tripadvisor.com/Attraction_Review-...      ออสติน
# 3    https://www.tripadvisor.com/Attraction_Review-...      ออสติน
# 4    https://www.tripadvisor.com/Attraction_Review-...      ออสติน
# ..                                                 ...         ...
# 130  https://www.tripadvisor.com/Attraction_Review-...   ซีแอตเทิล
# 131  https://www.tripadvisor.com/Attraction_Review-...   ซีแอตเทิล
# 132  https://www.tripadvisor.com/Attraction_Review-...   ซีแอตเทิล
# 133  https://www.tripadvisor.com/Attraction_Review-...   ซีแอตเทิล
# 134  https://www.tripadvisor.com/Attraction_Review-...   ซีแอตเทิล
#
#                                                   NAME  \
# 0                               พิพิธภัณฑ์ศิลปะบลานตัน
# 1                                      โรงละครโลกเดียว
# 2                                     ออสตินอะควาเรียม
# 3    "Myo" can be translated to Thai as "มิโย" if i...
# 4                                  บาร์ตัน สปริงส์ พูล
# ..                                                 ...
# 130                                   สวนก๊าซ เวิร์กส์
# 131                                       วงจรรีไซเคิล
# 132                             สวนประติมากรรมโอลิมปิก
# 133  Seattle Escape Games ترجم إلى Thai: เกมหนีในซี...
# 134             Discovery Park แปลว่า "อุทยานการค้นพบ"
#
#                                            DESCRIPTION  \
# 0    {'categories': array(['แกลเลอรีศิลปะ', 'จุดน่า...
# 1    {'categories': array(['โรงละคร'], dtype=object...
# 2    {'categories': array(['ตู้ปลา'], dtype=object)...
# 3    {'categories': array(['สปา'], dtype=object), '...
# 4    {'categories': array(['แหล่งน้ำ', 'น้ำพุร้อนแล...
# ..                                                 ...
# 130  {'categories': array(['สวนสาธารณะ'], dtype=obj...
# 131  {'หมวดหมู่': array(['การเช่าอุปกรณ์'], dtype=o...
# 132  {'หมวดหมู่': array(['สวนสาธารณะ'], dtype=objec...
# 133  {'categories': array(['เกมหลบหนี'], dtype=obje...
# 134  {'categories': array(['สวนสาธารณะ', 'เส้นทางแล...
#
#                                                REVIEWS
# 0    ["พิพิธภัณฑ์ศิลปะที่น่าทึ่ง เราได้ไปที่พิพิธภั...
# 1    ["สถานที่จัดคอนเสิร์ตที่ดีที่สุดในเท็กซัส นี่ค...
# 2    ["การเยี่ยมชมภายในบ้านที่ดีเหมาะกับครอบครัวขนา...
# 3    ["ไม่มีการนวดที่แย่เลย ฉันได้ไปเยือนสตูดิโอนวด...
# 4    ["คุณเคยเห็นซาลามานเดอร์ในสระน้ำไหม?, นี่ไม่ใช...
# ..                                                 ...
# 130  ["คุณต้องไปชมพระอาทิตย์ตกที่อุทยานแก๊สเวิร์ค! ...
# 131  ["ประสบการณ์การเช่าจักรยานที่ยอดเยี่ยม จักรยาน...
# 132  ["เดินง่ายพร้อมวิวสวยงาม นี่เป็นกิจกรรมที่ง่าย...
# 133  ["ยอดเยี่ยมสำหรับกิจกรรมสร้างทีมงาน เราจองเกมห...
# 134  ["การเดินป่าที่น่าพอใจภายในเขตเมือง, ผ่านมานาน...
#
# [135 rows x 7 columns]

# %%
from tqdm.auto import tqdm
import numpy as np
import pandas as pd
import math
import re, unicodedata, time

# data = dataset.to_pandas()
batch_size = 5

def is_missing(x):
    return x is None or (isinstance(x, float) and math.isnan(x))

def convert_to_native_types(obj):
    if obj is None:
        return ""
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    if isinstance(obj, np.integer):
        return int(obj)
    if isinstance(obj, np.floating):
        return "" if np.isnan(obj) else float(obj)
    if isinstance(obj, (list, tuple)):
        return [convert_to_native_types(v) for v in obj]
    if isinstance(obj, dict):
        return {k: convert_to_native_types(v) for k, v in obj.items()}
    return obj

def create_safe_id(destination, name, idx):
    destination = unicodedata.normalize('NFKD', str(destination or "")).encode('ASCII','ignore').decode('ASCII')
    name        = unicodedata.normalize('NFKD', str(name or "")).encode('ASCII','ignore').decode('ASCII')
    destination = re.sub(r'[^a-zA-Z0-9]+','_', destination).strip('_')
    name        = re.sub(r'[^a-zA-Z0-9]+','_', name).strip('_')
    return f"{destination}_{name}_{idx}"

# Store valid records
valid_ids = []
valid_embeds = []
valid_metadata = []
skipped = 0

for i in tqdm(range(0, len(data), batch_size)):
    batch = data.iloc[i:min(len(data), i+batch_size)]
    for idx, row in batch.iterrows():
        try:
            # ✅ Handle both dict or str DESCRIPTION
            desc_obj = row.get('DESCRIPTION', "")
            if isinstance(desc_obj, dict):
                desc_text = desc_obj.get('description', "")
            elif isinstance(desc_obj, str):
                desc_text = desc_obj
            else:
                desc_text = ""

            if not desc_text.strip():
                desc_text = "No description available."

            name = row.get('NAME', "") or ""
            dest = row.get('DESTINATION', "") or ""
            rating = row.get('RATING', 0.0)
            reviews = row.get('REVIEWS', [])
            url = row.get('URL', "") or ""

            # Some datasets have Thai list reviews, so force to list
            if not isinstance(reviews, list):
                reviews = [str(reviews)]

            # ✅ Text for embedding
            text_to_embed = f"ชื่อสถานที่: {name}\nสถานที่ตั้ง: {dest}\nรายละเอียด: {desc_text}\nรีวิว: {' '.join(reviews)}"

            embed = embed_model.embed_documents([text_to_embed])[0]
            record_id = create_safe_id(dest, name, idx)

            metadata_entry = convert_to_native_types({
                'text': desc_text,
                'name': name,
                'location': dest,
                'rating': 0.0 if is_missing(rating) else float(rating),
                'reviews': reviews,
                'url': url
            })

            valid_ids.append(record_id)
            valid_embeds.append(embed)
            valid_metadata.append(metadata_entry)

        except Exception as e:
            print(f"Error processing row {idx}: {e}")
            skipped += 1

    # ✅ Upsert per batch
    if valid_ids:
        sub_batch_size = 50
        for k in range(0, len(valid_ids), sub_batch_size):
            k_end = min(len(valid_ids), k+sub_batch_size)
            try:
                payload = list(zip(
                    valid_ids[k:k_end],
                    valid_embeds[k:k_end],
                    valid_metadata[k:k_end]
                ))
                index.upsert(vectors=payload)
                print(f"✅ Successfully upserted {k_end - k} records")
            except Exception as e:
                print(f"⚠️ Error upserting batch {k}-{k_end}: {e}")
                if k < len(valid_ids):
                    print(f"First ID in batch: {valid_ids[k]}")
        valid_ids.clear()
        valid_embeds.clear()
        valid_metadata.clear()

print(f"✅ Done! Skipped {skipped} rows due to errors.")
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Successfully upserted 5 records
# ✅ Done! Skipped 0 rows due to errors.

# %% [markdown]
# <hr>

# %%
# !pip -q install -U langchain-pinecone
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 6.8 MB/s eta 0:00:00

# %%
from pinecone import Pinecone
from langchain_pinecone import PineconeVectorStore

# Initialize Pinecone client
pc = Pinecone(api_key=pinecone_api)

# Connect to index (new API uses .index not .Index)
index = pc.Index("us-place-thai-all-mpnet-base-v2")   # still works in SDK
# or equivalently
# index = pc.index("us-places-ragv99")

# Create vector store wrapper
vectorstore = PineconeVectorStore(
    index=index,
    embedding=embed_model,    # pass full embedding object, not .embed_query
    text_key="text"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_pinecone/__init__.py:3: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   from langchain_pinecone.vectorstores import Pinecone, PineconeVectorStore

# %%
query = "อยากเที่ยว พิพิธภัณฑ์"
v = vectorstore.similarity_search(query, k = 3)
for i in v:
    print(i,end='\n')
# Out:
# page_content='{'ประเภท': ['โรงละคร'], 'คำอธิบาย': None}' metadata={'location': 'ไมอามี', 'name': 'ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด', 'rating': 4.5, 'reviews': ['["ช่วงเวลาที่น่าทึ่งที่ศูนย์อาร์ชท์ เพื่อน ๆ และฉันได้ไปสัมผัสนิทรรศการ Lasting Impressions นิทรรศการนี้ยอดเยี่ยมอย่างแท้จริง! ฉันไม่สามารถแนะนำได้ด้วยความกระตือรือร้นมากไปกว่านี้\n\nอย่างไรก็ตาม การรีวิวนี้พูดถึงพนักงานที่น่าทึ่งที่ศูนย์
าสองวัน โดยทั้งฉันและเพื่อนของฉันเลือกทำการนวดเต็มตัวแบบต่างกันและใช้บริการที่มีอยู่ (คุณสามารถอยู่ได้นานถึง 3 ชั่วโมง + เวลาการรักษา) \\n\\nเมื่อไปถึง เราได้รับการแนะนำไปที่ทางเข้าผู้หญิง และถูกพาผ่านสถานที่โดยพนักงานดูแลสปา; อธิบายว่าเราสามารถหาเสื้อผ้าได้ที่ไหน ต้องไปที่ไหนในช่วงเวลาการรักษา และจากนั้นก็ปล่อยให้เราจัดการกันเอง \\n\\nสิ่งอำนวยความสะดวกนั้นต่างไร้ที่ติในความเห็นของฉัน; มีการทำความสะอาดและเก็บกวาดอยู่เสมอโดยพนักงาน ไม่ดังหรือเงียบเกินไป มีตัวเลือกของอ่างน้ำและห้องมากมายให้เลือก ตู้เก็บของกว้างขวาง เสื้อคลุมและผ้าเช็ดตัวมีความหรูหรา และของใช้ส่วนตัวที่มีให้ใช้ก็ดูดีมาก มีสถานีอาหารว่าง และห้องชาเปิดให้บริการอย่างเต็มที่ และห้องเตรียมตัวนั้นมีทุกสิ่งที่คุณจำเป็นต้องใช้ \\n\\nการรักษาเองก็ยอดเยี่ยม (1 ครั้งนวดเต็มตัว และ 1 ครั้งนวดลึก) นักนวดของเราทั้งคู่เป็นมิตรและปรับการนวดตามความชอบของเรา \\n\\nเรายังไม่รู้ (หรือไม่ได้รับการบอก) ว่านี่คือสปาที่เลือกได้เรื่องเสื้อผ้าจนกว่าเราจะเช็คอินและถูกพาเดินดู เราเอาเสื้อว่ายน้ำติดไปด้วย และไม่มีปัญหาอะไร แต่ก็นับว่าเป็นเรื่องที่เซอร์ไพรส์นิดหน่อย ฉันต้องไม่โกหก! \\n\\nแน่นอนว่าเป็นการใช้จ่ายที่มาก แต่เราสนุกกับวันที่นี่และมุ่งหน้าไปยังเที่ยวบินคืนกลับบ้านด้วยความรู้สึกผ่อนคลายมาก :) เดินทางไปกับเพื่อน", "อืมมม.... เรามาที่นี่ทุกปีสำหรับการเดินทางประจำปีเพื่อการนวดของเรา สาเหตุส่วนหนึ่งเป็นเพราะสิ่งอำนวยความสะดวกอื่นๆ - ซาวน่า ห้องอบไอน้ำ สระว่ายน้ำ ห้องอาบน้ำ ฯลฯ นี่เป็นสถานที่ที่ยอดเยี่ยมในการผ่อนคลายและให้รางวัลตัวเองด้วยประสบการณ์ที่สงบสุข เราทั้ง 5 คนจองการนวด 80 นาที (ราคา $265 ต่อคน- เกิน $300 รวมทิปต่อคน) อย่างไรก็ตาม ไม่มีสิ่งอำนวยความสะดวกใดเปิดให้บริการ และไม่มีใครดูเหมือนจะแบ่งปันข้อมูลนี้กับเรา เราคาดว่าสิ่งอำนวยความสะดวกในห้องอาบน้ำจะเปิดให้บริการอย่างน้อย เนื่องจากการนวดใช้มันและต้องมีการอาบน้ำ สระว่ายน้ำในลาสเวกัสเปิดให้บริการ ดังนั้นเราคิดว่าสระว่ายน้ำในสปาคงเข้าถึงได้ ไม่มีอะไรที่เปิดให้บริการจริงๆ คุณสามารถเดินเข้ามา รอช่างเทคนิคที่พาคุณกลับไป และคุณถอดเสื้อผ้าในห้องที่คุณจะได้รับการนวด จากนั้นคุณก็จะได้สวมเสื้อผ้ากลับและถูกพาออกไปอย่างรวดเร็ว เข้าใจดีว่าทำไมถึงเป็นเช่นนี้เพราะโควิด! พวกเขาทำทุกอย่างที่จำเป็นเพื่อรักษาความสะอาด คุณต้องสวมหน้ากากตลอดเวลาซึ่งอาจทำให้รู้สึกไม่สบายเมื่อพยายามผ่อนคลาย คุณคิดว่าจะมีการลดราคาน้ำหนักลงเนื่องจากคุณไม่สามารถใช้สิ่งอำนวยความสะดวกได้เลย เราอาจจะไปที่อื่นหรือข้ามการนวดเหล่านี้ไปเลยหากเราทราบว่าไม่สามารถใช้บริการใด ๆ ได้เลย ราคาสูงมาก อย่างไรก็ตาม การนวดนั้นยอดเยี่ยมซึ่งก็คือจุดประสงค์ที่เรามาที่นี่ ใช้จ่ายไปมากกว่า $1500 นั้นถือว่าสูงเกินไป แต่มันก็เป็นความสบายดี เดินทางไปกับเพื่อน", "ประสบการณ์ที่น่าสนใจ ภรรยาของฉันและฉันได้สั่งการนวดไปด้วยกันทางออนไลน์ เมื่อเรามาถึง เราได้รับแจ้งว่าเราไม่สามารถทำการนวดคู่ได้ เนื่องจากแม้ว่าเราได้บอกออนไลน์ว่าเราจดทะเบียนสมรสแล้วและจองการนวดในเวลาเดียวกัน แต่เราไม่ได้จองการนวดแบบ \\"คู่\\" เพราะสิ่งนี้สามารถทำได้เพียงทางโทรศัพท์ ขอบคุณพระเจ้าที่พวกเขาย้ายบางสิ่งเพื่อเรา และเราขอบคุณมันมาก อย่างไรก็ตาม พวกเขาจำเป็นต้องปรับปรุงในส่วนนี้ทางออนไลน์ เพราะถ้าพวกเขาไม่สามารถทำให้มันเกิดขึ้นได้ เราคงจะพิจารณายกเลิกการจองของเรา\\n\\nสำหรับการนวดเอง เราเลือกนวดสวีดิชแบบดั้งเดิม และทั้งสองท่านนักนวดก็ยอดเยี่ยม เราสนุกกับเวลาของเราและรู้สึกผ่อนคลาย ฉันไม่คิดว่าเราจะทำแบบนี้อีก แต่สำหรับเรา นี่ถือเป็นครั้งแรกและเราพอใจมาก"]'], 'url': 'https://www.tripadvisor.com/Attraction_Review-g45963-d634862-Reviews-Qua_Baths_Spa-Las_Ve ...

# %%
query = "อยากเที่ยวได้ รายละเอียดเกี่ยวกับการท่องเที่ยวแนวธรรมชาติ"
v = vectorstore.similarity_search(query, k = 3)
for i in v:
    print(i,end='\n')
# Out:
เพื่อให้ประสบการณ์ของทุกคนเป็นเวลาที่ดีที่สุดเท่าที่จะเป็นไปได้ ฉันจะกลับไปที่ศูนย์อาร์ชท์ซ้ำแล้วซ้ำเล่า ถ้าไม่มีเหตุผลอื่นก็เพียงเพื่อให้คนเหล่านั้นได้ทำงานต่อไป!\n\nขอชมเชยศูนย์ที่มีโปรแกรมดี ๆ แต่ที่ยอดเยี่ยมกว่าคือพนักงานที่มีคุณภาพยอดเยี่ยม!!!, เดินทางกับเพื่อน ๆ", "ห้องคอนเสิร์ตที่สวยงาม พนักงานยอดเยี่ยม Cleveland Orchestra ในไมอามีเป็นสิ่งที่น่าตื่นตาตื่นใจเสมอ และห้องคอนเสิร์ต Knight ก็สวยงาม การจองตั๋วทำได้ง่าย และฉันอยากจะขอพูดถึงมาร์ตี้ เอช ในบ็อกซ์ออฟฟิศที่ตอบทุกคำถามของฉันทันท่วงทีและสุภาพและไม่สามารถให้ความช่วยเหลือได้มากกว่านี้ มาร์ตี้ช่วยจัดการปัญหาทั้งหมดและทำให้การเยี่ยมชมของเราเป็นไปอย่างสนุกสนานและไม่เครียด., เดินทางเป็นคู่", "WICKED ประสบการณ์ที่ยอดเยี่ยมเกิดขึ้นเมื่อเราดู Wicked ที่ศูนย์อาร์ชท์แอดเรียน นี่คือสิ่งที่ต้องดูอย่างแน่นอน! ที่นั่งในโอโบรส์ของเราเรียกได้ว่าเหนือระดับจริงๆ!! พนักงานดูแลให้ทุกคนอยู่ในระเบียบและช่วยในการหาที่นั่ง ขอให้ไปลองกันนะ!!, เดินทางเป็นคู่"]'], 'url': 'https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html'}

# %%
queries = [
    "อยากไปเที่ยวพิพิธภัณฑ์ในไมอามี่",
    "สถานที่เกี่ยวกับศิลปะและวัฒนธรรม" ,
    "อยากดูภาพจิตรกรรมฝาผนังหรือกราฟฟิตี้",
    "มีที่ไหนที่จัดแสดงผลงานศิลปะบ้าง",
    "อยากได้สถานที่ท่องเที่ยวที่เป็นมรดกทางวัฒนธรรม",
    "อยากเที่ยวกับครอบครัว",
    "สถานที่ที่เหมาะกับการพักผ่อน",
    "อยากไปถ่ายรูปสวยๆ",
    "สถานที่มีกิจกรรมสนุกๆ ให้ทำ",
    "อยากไปที่เหมาะกับเด็กๆ",
    "สถานที่ที่มีทั้งพิพิธภัณฑ์และสวนสวย",
    "อยากไปที่ที่มีสัตว์และสามารถเรียนรู้ได้ด้วย",
    "อยากเที่ยวแบบไม่ใช่ในตัวเมือง",
    "อยากได้ที่เที่ยวที่มีทั้งศิลปะและธรรมชาติ",
    "สถานที่ที่สามารถเรียนรู้ประวัติศาสตร์ของไมอามี่"
]
for q in queries:
    print(q)
    v = vectorstore.similarity_search_with_score(q,k=5)
    for i,score in v:
        page = str(i.page_content)
        if "array([" in page:
            try:
                cat_part = page.split("array([")[1].split("],")[0]
            except Exception:
                cat_part = "-"
        else:
            cat_part = "-"
        # print(i)
        print(f"- Place : {i.metadata.get('name','?')}")
        print(f"    - Score    : {score:.5f}")
        print(f"    - Category : {cat_part}")
        print(f"    - Position : {i.metadata.get('location','?')}")
        print(f"    - url      : {i.metadata.get('url','?')}")

    print()
# Out:
# อยากไปเที่ยวพิพิธภัณฑ์ในไมอามี่
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# สถานที่เกี่ยวกับศิลปะและวัฒนธรรม
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# อยากดูภาพจิตรกรรมฝาผนังหรือกราฟฟิตี้
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# มีที่ไหนที่จัดแสดงผลงานศิลปะบ้าง
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# อยากได้สถานที่ท่องเที่ยวที่เป็นมรดกทางวัฒนธรรม
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# อยากเที่ยวกับครอบครัว
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# สถานที่ที่เหมาะกับการพักผ่อน
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# อยากไปถ่ายรูปสวยๆ
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# สถานที่มีกิจกรรมสนุกๆ ให้ทำ
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.49988
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : เวซูเวียโอ คาเฟ่
#     - Score    : 0.49569
#     - Category : -
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d156726-Reviews-Vesuvio_Cafe-San_Francisco_California.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.48331
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.47369
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : ศูนย์วัฒนธรรมชิคาโก
#     - Score    : 0.47355
#     - Category : -
#     - Position : ชิคาโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g35805-d103785-Reviews-Chicago_Cultural_Center-Chicago_Illinois.html
#
# อยากไปที่เหมาะกับเด็กๆ
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# สถานที่ที่มีทั้งพิพิธภัณฑ์และสวนสวย
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# อยากไปที่ที่มีสัตว์และสามารถเรียนรู้ได้ด้วย
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# อยากเที่ยวแบบไม่ใช่ในตัวเมือง
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# อยากได้ที่เที่ยวที่มีทั้งศิลปะและธรรมชาติ
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
#
# สถานที่ที่สามารถเรียนรู้ประวัติศาสตร์ของไมอามี่
# - Place : ทราเปซ ลาสเวกัส
#     - Score    : 0.41054
#     - Category : 'บทเรียนและการอบรม'
#     - Position : ลาสเวกัส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g45963-d3850233-Reviews-Trapeze_Las_Vegas-Las_Vegas_Nevada.html
# - Place : โรงละครเคอแรน
#     - Score    : 0.40992
#     - Category : 'โรงภาพยนตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d4039071-Reviews-Curran_Theatre-San_Francisco_California.html
# - Place : Seattle Escape Games ترجم إلى Thai: เกมหนีในซีแอตเทิล
#     - Score    : 0.39797
#     - Category : 'เกมหลบหนี'
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12287361-Reviews-Seattle_Escape_Games-Seattle_Washington.html
# - Place : ซีแอตเทิล เอ็กซ์เพรส
#     - Score    : 0.39614
#     - Category : -
#     - Position : ซีแอตเทิล
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60878-d12110220-Reviews-Seattle_Express-Seattle_Washington.html
# - Place : ศูนย์ศิลปการแสดงแอเดรียน อาร์ชต์ สำหรับเทศมณฑลไมอามี-เดด
#     - Score    : 0.39536
#     - Category : -
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d642917-Reviews-Adrienne_Arsht_Center_for_the_Performing_Arts_of_Miami_Dade_County-Miami_Florida.html
