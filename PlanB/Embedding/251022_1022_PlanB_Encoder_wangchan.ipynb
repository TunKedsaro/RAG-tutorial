# %%
# !pip -q install langchain openai pinecone langchain-huggingface
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.6/587.6 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.3/259.3 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 3.2 MB/s eta 0:00:00

# %%
from datasets import load_dataset

# %%
from google.colab import userdata
pinecone_api = userdata.get('PINECONE_API_KEY')

# %%
from pinecone import ServerlessSpec

# %%
spec = ServerlessSpec(
    cloud  = "aws",
    region = "us-east-1"
)

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
# load embedding
embeddings  = HuggingFaceEmbeddings(model_name = "airesearch/wangchanberta-base-att-spm-uncased")
embed_model = embeddings
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name airesearch/wangchanberta-base-att-spm-uncased. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/546 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/423M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/282 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/905k [00:00<?, ?B/s]

# %%
embed = embed_model.embed_documents("ฝนตกหนักถล่มภาพเหนือ")
len(embed),len(embed[0])
# Out:
# (20, 768)

# %%
import time
from pinecone import Pinecone

# %%
pc = Pinecone(api_key = pinecone_api)
index_name = "us-place-thai-wangchanberta"
existing_indexes = [index_info["name"] for index_info in pc.list_indexes()]
if index_name not in existing_indexes:
    pc.create_index(index_name,dimension = 768, metric = 'dotproduct', spec = spec)
    while not pc.describe_index(index_name).status['ready']:
        time.sleep(1)
    print(f"Create vector database name {index_name} successfull !")
else:
    print(f"Aready got vector database name {index_name} !!!")
# Out:
# Aready got vector database name us-place-thai-wangchanberta !!!

# %%
index = pc.Index(index_name)
time.sleep(1)
index.describe_index_stats()
# Out:
# {'dimension': 768,
#  'index_fullness': 0.0,
#  'metric': 'dotproduct',
#  'namespaces': {},
#  'total_vector_count': 0,
#  'vector_type': 'dense'}

# %%
from datasets import load_dataset

# %%
dataset = load_dataset(
    "Tun555/us-places-thai",
    split = "train"
)
data = dataset.to_pandas()
data["DESTINATION"] = data["DESTINATION_TH"]
data["NAME"] = data["NAME_TH"]
data["DESCRIPTION"] = data["DESCRIPTION_TH"]
data["REVIEWS"] = data["REVIEWS_TH"]
data = data[['RATING', 'PICTURE','URL', 'DESTINATION', 'NAME', 'DESCRIPTION', 'REVIEWS']]
data
# Out:
# README.md:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# train.csv: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/135 [00:00<?, ? examples/s]
#      RATING                                            PICTURE  \
# 0       4.5  https://dynamic-media-cdn.tripadvisor.com/medi...
# 1       4.5  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2       4.0                                               None
# 3       5.0  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4       4.5  https://dynamic-media-cdn.tripadvisor.com/medi...
# ..      ...                                                ...
# 130     4.5  https://dynamic-media-cdn.tripadvisor.com/medi...
# 131     5.0  https://dynamic-media-cdn.tripadvisor.com/medi...
# 132     4.0  https://dynamic-media-cdn.tripadvisor.com/medi...
# 133     5.0  https://dynamic-media-cdn.tripadvisor.com/medi...
# 134     4.5  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                    URL DESTINATION  \
# 0    https://www.tripadvisor.com/Attraction_Review-...      ออสติน
# 1    https://www.tripadvisor.com/Attraction_Review-...      ออสติน
# 2    https://www.tripadvisor.com/Attraction_Review-...      ออสติน
# 3    https://www.tripadvisor.com/Attraction_Review-...      ออสติน
# 4    https://www.tripadvisor.com/Attraction_Review-...      ออสติน
# ..                                                 ...         ...
# 130  https://www.tripadvisor.com/Attraction_Review-...   ซีแอตเทิล
# 131  https://www.tripadvisor.com/Attraction_Review-...   ซีแอตเทิล
# 132  https://www.tripadvisor.com/Attraction_Review-...   ซีแอตเทิล
# 133  https://www.tripadvisor.com/Attraction_Review-...   ซีแอตเทิล
# 134  https://www.tripadvisor.com/Attraction_Review-...   ซีแอตเทิล
#
#                                                   NAME  \
# 0                               พิพิธภัณฑ์ศิลปะบลานตัน
# 1                                      โรงละครโลกเดียว
# 2                                     ออสตินอะควาเรียม
# 3    "Myo" can be translated to Thai as "มิโย" if i...
# 4                                  บาร์ตัน สปริงส์ พูล
# ..                                                 ...
# 130                                   สวนก๊าซ เวิร์กส์
# 131                                       วงจรรีไซเคิล
# 132                             สวนประติมากรรมโอลิมปิก
# 133  Seattle Escape Games ترجم إلى Thai: เกมหนีในซี...
# 134             Discovery Park แปลว่า "อุทยานการค้นพบ"
#
#                                            DESCRIPTION  \
# 0    {'categories': array(['แกลเลอรีศิลปะ', 'จุดน่า...
# 1    {'categories': array(['โรงละคร'], dtype=object...
# 2    {'categories': array(['ตู้ปลา'], dtype=object)...
# 3    {'categories': array(['สปา'], dtype=object), '...
# 4    {'categories': array(['แหล่งน้ำ', 'น้ำพุร้อนแล...
# ..                                                 ...
# 130  {'categories': array(['สวนสาธารณะ'], dtype=obj...
# 131  {'หมวดหมู่': array(['การเช่าอุปกรณ์'], dtype=o...
# 132  {'หมวดหมู่': array(['สวนสาธารณะ'], dtype=objec...
# 133  {'categories': array(['เกมหลบหนี'], dtype=obje...
# 134  {'categories': array(['สวนสาธารณะ', 'เส้นทางแล...
#
#                                                REVIEWS
# 0    ["พิพิธภัณฑ์ศิลปะที่น่าทึ่ง เราได้ไปที่พิพิธภั...
# 1    ["สถานที่จัดคอนเสิร์ตที่ดีที่สุดในเท็กซัส นี่ค...
# 2    ["การเยี่ยมชมภายในบ้านที่ดีเหมาะกับครอบครัวขนา...
# 3    ["ไม่มีการนวดที่แย่เลย ฉันได้ไปเยือนสตูดิโอนวด...
# 4    ["คุณเคยเห็นซาลามานเดอร์ในสระน้ำไหม?, นี่ไม่ใช...
# ..                                                 ...
# 130  ["คุณต้องไปชมพระอาทิตย์ตกที่อุทยานแก๊สเวิร์ค! ...
# 131  ["ประสบการณ์การเช่าจักรยานที่ยอดเยี่ยม จักรยาน...
# 132  ["เดินง่ายพร้อมวิวสวยงาม นี่เป็นกิจกรรมที่ง่าย...
# 133  ["ยอดเยี่ยมสำหรับกิจกรรมสร้างทีมงาน เราจองเกมห...
# 134  ["การเดินป่าที่น่าพอใจภายในเขตเมือง, ผ่านมานาน...
#
# [135 rows x 7 columns]

# %%
from tqdm.auto import tqdm
import numpy as np
import pandas as pd
import math
import re, unicodedata, time

# data = dataset.to_pandas()
batch_size = 5

def is_missing(x):
    return x is None or (isinstance(x, float) and math.isnan(x))

def convert_to_native_types(obj):
    if obj is None:
        return ""
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    if isinstance(obj, np.integer):
        return int(obj)
    if isinstance(obj, np.floating):
        return "" if np.isnan(obj) else float(obj)
    if isinstance(obj, (list, tuple)):
        return [convert_to_native_types(v) for v in obj]
    if isinstance(obj, dict):
        return {k: convert_to_native_types(v) for k, v in obj.items()}
    return obj

def create_safe_id(destination, name, idx):
    destination = unicodedata.normalize('NFKD', str(destination or "")).encode('ASCII','ignore').decode('ASCII')
    name        = unicodedata.normalize('NFKD', str(name or "")).encode('ASCII','ignore').decode('ASCII')
    destination = re.sub(r'[^a-zA-Z0-9]+','_', destination).strip('_')
    name        = re.sub(r'[^a-zA-Z0-9]+','_', name).strip('_')
    return f"{destination}_{name}_{idx}"

# Store valid records
valid_ids = []
valid_embeds = []
valid_metadata = []
skipped = 0

for i in tqdm(range(0, len(data), batch_size)):
    batch = data.iloc[i:min(len(data), i+batch_size)]
    for idx, row in batch.iterrows():
        try:
            # Handle both dict or str DESCRIPTION
            desc_obj = row.get('DESCRIPTION', "")
            if isinstance(desc_obj, dict):
                desc_text = desc_obj.get('description', "")
            elif isinstance(desc_obj, str):
                desc_text = desc_obj
            else:
                desc_text = ""

            if not desc_text.strip():
                desc_text = "No description available."

            name = row.get('NAME', "") or ""
            dest = row.get('DESTINATION', "") or ""
            rating = row.get('RATING', 0.0)
            reviews = row.get('REVIEWS', [])
            url = row.get('URL', "") or ""

            # Some datasets have Thai list reviews, so force to list
            if not isinstance(reviews, list):
                reviews = [str(reviews)]

            # Text for embedding
            text_to_embed = f"ชื่อสถานที่: {name}\nสถานที่ตั้ง: {dest}\nรายละเอียด: {desc_text}\nรีวิว: {' '.join(reviews)}"

            embed = embed_model.embed_documents([text_to_embed])[0]
            record_id = create_safe_id(dest, name, idx)

            metadata_entry = convert_to_native_types({
                'text': desc_text,
                'name': name,
                'location': dest,
                'rating': 0.0 if is_missing(rating) else float(rating),
                'reviews': reviews,
                'url': url
            })

            valid_ids.append(record_id)
            valid_embeds.append(embed)
            valid_metadata.append(metadata_entry)

        except Exception as e:
            print(f"Error processing row {idx}: {e}")
            skipped += 1

    # Upsert per batch
    if valid_ids:
        sub_batch_size = 50
        for k in range(0, len(valid_ids), sub_batch_size):
            k_end = min(len(valid_ids), k+sub_batch_size)
            try:
                payload = list(zip(
                    valid_ids[k:k_end],
                    valid_embeds[k:k_end],
                    valid_metadata[k:k_end]
                ))
                index.upsert(vectors=payload)
                print(f"✅ Successfully upserted {k_end - k} records")
            except Exception as e:
                print(f"⚠️ Error upserting batch {k}-{k_end}: {e}")
                if k < len(valid_ids):
                    print(f"First ID in batch: {valid_ids[k]}")
        valid_ids.clear()
        valid_embeds.clear()
        valid_metadata.clear()

print(f"✅ Done! Skipped {skipped} rows due to errors.")
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# Error processing row 0: index out of range in self
# Error processing row 2: index out of range in self
# Error processing row 3: index out of range in self
# Error processing row 4: index out of range in self
# ✅ Successfully upserted 1 records
# ✅ Successfully upserted 5 records
# Error processing row 11: index out of range in self
# Error processing row 13: index out of range in self
# Error processing row 14: index out of range in self
# ✅ Successfully upserted 2 records
# Error processing row 15: index out of range in self
# Error processing row 16: index out of range in self
# Error processing row 19: index out of range in self
# ✅ Successfully upserted 2 records
# Error processing row 20: index out of range in self
# Error processing row 22: index out of range in self
# Error processing row 24: index out of range in self
# ✅ Successfully upserted 2 records
# Error processing row 25: index out of range in self
# Error processing row 28: index out of range in self
# Error processing row 29: index out of range in self
# ✅ Successfully upserted 2 records
# Error processing row 30: index out of range in self
# ✅ Successfully upserted 4 records
# Error processing row 37: index out of range in self
# Error processing row 39: index out of range in self
# ✅ Successfully upserted 3 records
# Error processing row 40: index out of range in self
# Error processing row 41: index out of range in self
# Error processing row 42: index out of range in self
# Error processing row 44: index out of range in self
# ✅ Successfully upserted 1 records
# Error processing row 45: index out of range in self
# Error processing row 48: index out of range in self
# ✅ Successfully upserted 3 records
# Error processing row 50: index out of range in self
# Error processing row 52: index out of range in self
# Error processing row 53: index out of range in self
# Error processing row 54: index out of range in self
# ✅ Successfully upserted 1 records
# Error processing row 55: index out of range in self
# Error processing row 58: index out of range in self
# Error processing row 59: index out of range in self
# ✅ Successfully upserted 2 records
# Error processing row 60: index out of range in self
# Error processing row 61: index out of range in self
# Error processing row 63: index out of range in self
# ✅ Successfully upserted 2 records
# Error processing row 65: index out of range in self
# Error processing row 68: index out of range in self
# Error processing row 69: index out of range in self
# ✅ Successfully upserted 2 records
# Error processing row 70: index out of range in self
# Error processing row 71: index out of range in self
# Error processing row 73: index out of range in self
# Error processing row 74: index out of range in self
# ✅ Successfully upserted 1 records
# Error processing row 75: index out of range in self
# Error processing row 76: index out of range in self
# Error processing row 78: index out of range in self
# Error processing row 79: index out of range in self
# ✅ Successfully upserted 1 records
# Error processing row 80: index out of range in self
# Error processing row 82: index out of range in self
# Error processing row 83: index out of range in self
# Error processing row 84: index out of range in self
# ✅ Successfully upserted 1 records
# Error processing row 85: index out of range in self
# ✅ Successfully upserted 4 records
# Error processing row 90: index out of range in self
# Error processing row 92: index out of range in self
# Error processing row 93: index out of range in self
# ✅ Successfully upserted 2 records
# ✅ Successfully upserted 5 records
# Error processing row 102: index out of range in self
# Error processing row 104: index out of range in self
# ✅ Successfully upserted 3 records
# Error processing row 107: index out of range in self
# Error processing row 108: index out of range in self
# ✅ Successfully upserted 3 records
# ✅ Successfully upserted 5 records
# Error processing row 116: index out of range in self
# Error processing row 118: index out of range in self
# ✅ Successfully upserted 3 records
# Error processing row 120: index out of range in self
# Error processing row 121: index out of range in self
# Error processing row 122: index out of range in self
# Error processing row 123: index out of range in self
# ✅ Successfully upserted 1 records
# Error processing row 128: index out of range in self
# Error processing row 129: index out of range in self
# ✅ Successfully upserted 3 records
# Error processing row 130: index out of range in self
# Error processing row 133: index out of range in self
# Error processing row 134: index out of range in self
# ✅ Successfully upserted 2 records
# ✅ Done! Skipped 69 rows due to errors.

# %%
# !pip install -U langchain-pinecone
# Out:
# Collecting langchain-pinecone
#   Downloading langchain_pinecone-0.2.12-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.34 in /usr/local/lib/python3.12/dist-packages (from langchain-pinecone) (0.3.79)
# Requirement already satisfied: pinecone<8.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (7.3.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from langchain-pinecone) (2.0.2)
# Collecting langchain-openai>=0.3.11 (from langchain-pinecone)
#   Downloading langchain_openai-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: httpx>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from langchain-pinecone) (0.28.1)
# Requirement already satisfied: simsimd>=5.9.11 in /usr/local/lib/python3.12/dist-packages (from langchain-pinecone) (6.5.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.0->langchain-pinecone) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.0->langchain-pinecone) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.0->langchain-pinecone) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.0->langchain-pinecone) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.0->langchain-pinecone) (0.16.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.4.37)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.11.10)
# INFO: pip is looking at multiple versions of langchain-openai to determine which version is compatible with other requirements. This could take a while.
#   Downloading langchain_openai-1.0.0-py3-none-any.whl.metadata (1.8 kB)
#   Downloading langchain_openai-0.3.35-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in /usr/local/lib/python3.12/dist-packages (from langchain-openai>=0.3.11->langchain-pinecone) (1.109.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai>=0.3.11->langchain-pinecone) (0.12.0)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.12/dist-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.5.0)
# Requirement already satisfied: aiohttp>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.13.1)
# Collecting aiohttp-retry<3.0.0,>=2.9.1 (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone)
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.22.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.25.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.104.2->langchain-openai>=0.3.11->langchain-pinecone) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.104.2->langchain-openai>=0.3.11->langchain-pinecone) (0.11.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.104.2->langchain-openai>=0.3.11->langchain-pinecone) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.104.2->langchain-openai>=0.3.11->langchain-pinecone) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.5.3->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.17.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai>=0.3.11->langchain-pinecone) (2024.11.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (3.4.4)
# Downloading langchain_pinecone-0.2.12-py3-none-any.whl (25 kB)
# Downloading langchain_openai-0.3.35-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 3.4 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Installing collected packages: aiohttp-retry, langchain-openai, langchain-pinecone
# Successfully installed aiohttp-retry-2.9.1 langchain-openai-0.3.35 langchain-pinecone-0.2.12

# %%
from pinecone import Pinecone
from langchain_pinecone import PineconeVectorStore

# Initialize Pinecone client
pc = Pinecone(api_key=pinecone_api)

# Connect to index (new API uses .index not .Index)
index = pc.Index("us-place-thai-wangchanberta")   # still works in SDK
# or equivalently
# index = pc.index("us-places-ragv99")

# Create vector store wrapper
vectorstore = PineconeVectorStore(
    index=index,
    embedding=embed_model,    # pass full embedding object, not .embed_query
    text_key="text"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_pinecone/__init__.py:3: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   from langchain_pinecone.vectorstores import Pinecone, PineconeVectorStore

# %%
query = "อยากเที่ยว พิพิธภัณฑ์"
v = vectorstore.similarity_search(query, k = 3)
for i in v:
    print(i,end='\n')
# Out:
# page_content='{'หมวดหมู่': array(['อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'], dtype=object), 'คำอธิบาย': None}' metadata={'location': 'ออสติน', 'name': 'อาสนวิหารเซนต์แมรี่', 'rating': 4.5, 'reviews': ['["การรำลึกถึงรากฐานชาวไอริชของเมือง ชุมชนคาทอลิกชาวไอริชที่ก่อตั้งมหาวิหารเซนต์แมรีในออสติน รัฐเท็กซัส มีต้นกำเนิดในทศวรรษ 1850 เมื่อมีการสร้างโบสถ์หินเล็กๆ ที่ชื่อว่าเซนต์แพทริค บนมุมถนน 9 และบราชอส ในปี 1866 วัดได้ตัดสินใจว่าพวกเขาต้องการโบสถ์ใหม่ ในปี 1872 หลังจากที่ออสตินถูกกำหนดให้เป็นเมืองหลวงถาวรของเท็กซัส วัดได้วางศิลาฤกษ์สำหรับโบสถ์ใหม่ที่ 203 ถนนอีสต์ 10 ซึ่งอยู่หนึ่งช่วงตึกทางเหนือจากอาคารเดิม โบสถ์เสร็จสมบูรณ์ในปี 1874 และมีการถวายในมหาวิหารเซนต์แมรีในปี 1884 ออกแบบโดยสถาปนิกเกิดที่ไอร์แลนด์ นิโคลัส เจ. เคลย์ตัน สไตล์ของมันเป็นแบบวิคตอเรียที่มีหอคอยและยอดแบบนีโอ-โกธิก เป็นหนึ่งในระฆังที่ใหญ่ที่สุดในรัฐ มีหน้าต่างกระจกสี โค้งไม้ที่ตั้งอยู่บนประตูและหน้าต่าง ภาพจิตรกรรมสีสันสดใส และเพดานและโดมสีน้ำเงินที่ประดับด้วยดวงดาวซึ่งสะท้อนท้องฟ้าและสวรรค์ มหาวิหาร underwent การบูรณะอย่างกว้างขวางในปี 2013 หนึ่งในโครงการสำคัญคือหน้าต่างกุหลาบขนาดใหญ่ที่ด้านหน้าส่วนหน้า การออกแบบกลางของ 퀸쿱ซ์ ซึ่งมีสี่ส่วนหมุนออกจากหนึ่ง สามารถตีความได้ว่าเป็นการแสดงผลเชิงเรขาคณิตของสี่นักบุญที่นำคำสอนไปยังสี่มุมของโลก อาคารได้รับการกำหนดให้เป็นสถานที่ประวัติศาสตร์แห่งรัฐเท็กซัสในปี 1977 และถูกเพิ่มเข้ามาในทะเบียนสถานที่ประวัติศาสตร์แห่งชาติในปี 1973 อีกข้อสังเกตที่น่าสนใจ: โรงเรียนของมหาวิหารเซนต์แมรี ซึ่งก่อตั้งขึ้นในปี 1866 เป็นโรงเรียนที่เก่าแก่ที่สุดในออสตินที่ยังคงดำเนินกิจการอย่างต่อเนื่อง","โบสถ์ที่งดงาม สถาปัตยกรรมคลาสสิกใช้หินในท้องถิ่น\\n\\nน่าเสียดายที่เราไปเยี่ยมในบ่ายที่มีหมอกมาก ดังนั้นสีภายในจึงไม่สดใส\\n\\nหน้าต่างกระจกสีที่สวยงามและโค้งไม้และขอบที่สวยงาม","มิสซาลาติน ฉันแวะเข้าไปสวดมนต์และดีใจที่ได้ทำเช่นนั้น ช่วงบ่ายในวันธรรมดาและมีคนอื่นประมาณห้าคนที่ทำเช่นเดียวกัน สถานที่มีความงดงามแต่เรียบง่าย ฉันสังเกตว่าพวกเขามีมิสซาลาตินซึ่งฉันไม่รู้ว่าหาได้อีก ยังไงก็ตาม ฉันคัดค้านการปฏิบัติเช่นนี้ซึ่งย้อนกลับไปในช่วงเวลาที่ควบคุมโดยสงฆ์อย่างเต็มที่ ก่อนที่วาติกันจะประชุมครั้งที่สอง แต่ฉันก็ไม่ได้รู้สึกอึดอัดที่มันเป็นทางเลือกสำหรับบางคน อาจจะเป็นวิธีที่ดีที่สุดในการสัมผัสสิ่งนี้คือการเข้าร่วมพิธีลาตินซักครั้งหนึ่ง","เดินทางคนเดียว"]'], 'url': 'https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html'}
# page_content='{'categories': array(['สวนสาธารณะ', 'สนามเด็กเล่น'], dtype=object), 'description': 'ระยะเวลาที่แนะนำ'}' metadata={'location': 'ซานฟรานซิสโก', 'name': 'โปร์ทสมัธ สแควร์', 'rating': 4.0, 'reviews': ['["ประสบการณ์ทางวัฒนธรรมที่น่าพอใจ\\n\\nในเดือนสิงหาคม ฉันได้เดินเล่นในไชน่าทาวน์นาน ๆ และจบที่พอร์ทสมุทรสแควร์ ซึ่งเป็นบล็อกคอนกรีตและสนามหญ้า ขอบเขตทางด้านตะวันตกติดกับ Walter U Lum Place (ถนนเล็กมาก) ทางเหนือคือ Washington St ทางใต้คือ Clay St และบริเวณขอบทางด้านตะวันออกของไชน่าทาวน์คือ Kearney St ซึ่งเป็นจุดเริ่มต้นของเขตการเงินอย่างเป็นทางการ\\n\\nหลายปีก่อน ฉันเคยไปที่พอร์ทสมุทรสแควร์ครั้งแรกเมื่อเราพักที่ฮิลตันเขตการเงิน ซึ่งอยู่ฝั่งตรงข้ามถนนและเชื่อมต่อกับสแควร์ผ่านสะพานคนเดิน ศูนย์วัฒนธรรมจีนตั้งอยู่ในฮิลตัน บนระดับสะพาน แต่ฉันไม่เคยพบว่ามันเปิดให้บริการ เนื่องจากในครั้งนี้ฉันไม่ได้ข้ามสะพาน ฉันจึงไม่สามารถบอกได้ว่ามันเปิดหรือไม่\\n\\nพอร์ทสมุทรสแควร์เป็นสถานที่พบปะ และสำหรับชาวบ้านที่อยู่ใกล้เคียง หลายคนในนั้นมีเชื้อสายเอเชีย พื้นที่นี้เหมาะสำหรับการผลักรถเข็นเด็ก ให้เด็ก ๆ ได้เล่น และผู้ใหญ่ได้เล่นเกมกระดานที่มีโต๊ะและม้านั่งมากมาย\\n\\nยังเช้าอยู่มากในวันทำงานฤดูร้อน ดังนั้นสแควร์จึงยังไม่ค่อยมีผู้คนใช้สอย - ขณะนั้น ฉันสังเกตเห็นว่าในวันอาทิตย์พื้นที่นั้นจะเต็มไปด้วยผู้คนมากกว่าเวลาปกติ\\n\\nแม้ว่าการจราจรบน Kearney St จะค่อนข้างหนาแน่นตลอดเวลา แต่ด้วยการยกระดับของสแควร์ที่ขอบด้านตะวันออกทำให้พื้นที่นี้แยกออกจากการจราจรส่วนใหญ่ - ดูเหมือนจะห่างไกลจากโลกภายนอก\\n\\nเมื่อมีผู้คนมากขึ้น มันเป็นสถานที่ที่ดีในการซึมซับวัฒนธรรมเอเชียเล็กน้อย และเพลิดเพลินกับโอเอซิสนี้ในเมือง", "ผู้คนที่น่าสนใจในไชน่าทาวน์ กลางจัตุรัสสาธารณะ ซึ่งทำหน้าที่เหมือนเป็นศูนย์กลางชุมชนที่ชาวบ้านเล่นการ์ดและทำกิจกรรมอื่น ๆ เป็นสถานที่น่าไปในเวลากลางวัน วันหนึ่งเราผ่านไปในตอนกลางคืน และพื้นที่นั้นมีบรรยากาศที่ไม่ค่อยดีนัก", "พื้นที่รวมตัวสาธารณะ สนามเด็กเล่น - พอร์ทสมุทรสแควร์ ไชน่าทาวน์ ซานฟรานซิสโก ฉันไปที่พอร์ทสมุทรสแควร์ในย่านไชน่าทาวน์ของซานฟรานซิสโก\\n\\nนี่คือพื้นที่รวมตัวสาธารณะ ชาวบ้านอาจจะกำลังเล่นมะฮฺจง\\n\\nมีสนามเด็กเล่น\\n\\nยังเป็นสถานที่ตั้งของโรงเรียนรัฐบาลแห่งแรกในรัฐแคลิฟอร์เนียอีกด้วย"]'], 'url': 'https://www.tripadvisor.com/Attraction_Review-g60713-d7751526-Reviews-Portsmouth_Square-San_Francisco_California.html'}
# page_content='{'หมวดหมู่': array(['สวนสาธารณะ', 'สวน'], dtype=object), 'คำอธิบาย': 'ระยะเวลาที่แนะนำ'}' metadata={'location': 'ซานฟรานซิสโก', 'name': 'อัลตาพลาซ่า พาร์ค', 'rating': 4.5, 'reviews': ['["สวนสาธารณะซานฟรานซิสโกที่สวยงาม นี่คือหนึ่งในพื้นที่สีเขียวกลางแจ้งที่สวยงามของซานฟรานซิสโก อัลตาพาร์คเป็นการรวมกันของพื้นที่หญ้าขนาดใหญ่สำหรับการปูผ้าปูที่นอนและปิกนิก ทิวทัศน์ที่สวยงามของเมือง และสนามเด็กเล่นสำหรับเด็ก ๆ \\n\\nในวันที่มีลมพัด อาจจะมีอากาศเย็นลงกว่าสักสองสามองศาที่นี่เมื่อเปรียบเทียบกับถนนฟิลมอร์ ในขณะที่สวนนี้น่าจะถูกออกแบบมาเพื่อคนท้องถิ่น แต่ดิฉันขอแนะนำให้หยุดที่นี่ระหว่างการเดินป่าครอสซานฟรานซิสโกสำหรับนักท่องเที่ยวและคนท้องถิ่นด้วยเช่นกัน\\n\\nและถ้าคุณมีสุนัข ให้นำมาด้วยค่ะ, เดินทางคนเดียว", "วิวทิวทัศน์...และสถาปัตยกรรม...และความเป็นฮอลลีวูดเล็กน้อย สถานที่ที่สวยงามพร้อมวิวที่น่าทึ่ง เป็นสถานที่ที่คนท้องถิ่นเล่นเทนนิสและพาสุนัขมาออกกำลังกาย\\n\\nแต่ว่าสวนนี้มีความเชื่อมโยงกับฮอลลีวูด บันไดใหญ่ได้ถูกใช้ในภาพยนตร์ \\"What\'s Up, Doc?\\" และความเสียหายที่เกิดจากรถยนต์สี่คันที่ขับลงบันไดยังคงมองเห็นได้ในปี 2022 นอกจากนี้ยังปรากฏในภาพยนตร์เรื่อง \\"The Conversation\\" ของคอปโปล่า \\n\\nสถาปัตยกรรมในพื้นที่นี้น่าทึ่ง ไม่มีที่ใดที่น่าประทับใจไปกว่าอพาร์ตเมนต์อัลต้าพลาซ่าที่ตั้งอยู่ติดกับสวน สร้างขึ้นในยุคก่อนหน้านี้เมื่ออาคารตั้งตระหง่านขึ้นไป เป็นตัวอย่างที่โดดเด่นของความหรูหราของช่วงทศวรรษที่ 20 อาคารนี้ออกแบบโดยสถาปนิกท้องถิ่น คอนราด เอ. เมาส์ดอร์ฟเฟอร์ ซึ่งเป็นอัญมณีที่น่าทึ่งมาก \\n\\nใกล้ ๆ เนินเขาลดระดับลงสู่ทะเลสาบ มันเป็นประสบการณ์ที่น่าตื่นเต้นสำหรับผู้โดยสารใหม่บนรถบัส 22 ฟิลมอร์ซึ่งไม่รู้ว่ารถบัสจะเลี้ยวออกจากทางลาดชัน \\nแค่นั้นค่ะ, เดินทางคนเดียว", "สวนสาธารณะและสนามเด็กเล่นที่สวยงามพร้อมวิวที่น่าทึ่ง สวนที่สวยงามพร้อมวิวที่ยอดเยี่ยมและร้านอาหารอยู่ห่างออกไปไม่กี่ช่วงตึก เราได้มาเยือนที่นี่หลายครั้งเพราะเป็นสถานที่ที่เจ้าของสุนัขพันธุ์คาวาเลียร์คิงชาร์ลส์สแปเนียลกว่า 20 คนมารวมตัวกันพาสุนัขของเราเล่นเป็นเวลาสองสามชั่วโมง\\n\\nเราชอบเห็นเด็ก ๆ ในสนามเด็กเล่นและผู้คนปิกนิกบนสนามหญ้า"]'], 'url': 'https://www.tripadvisor.com/Attraction_Review-g60713-d7733962-Reviews-Alta_Plaza_Park-San_Francisco_California.html'}

# %%
query = "อยากเที่ยวได้ รายละเอียดเกี่ยวกับการท่องเที่ยวแนวธรรมชาติ"
v = vectorstore.similarity_search(query, k = 3)
for i in v:
    print(i,end='\n')
# Out:
# page_content='{'categories': array(['พิพิธภัณฑ์เฉพาะทาง'], dtype=object), 'description': 'ที่ตั้งสำนักงานใหญ่ดั้งเดิมของมิชชั่นนารีโปรเตสแตนท์ชาวอเมริกันในศตวรรษที่ 19 พิพิธภัณฑ์นี้อธิบายประวัติศาสตร์ของมิชชั่นนารีอเมริกันในฮาวาย.'}' metadata={'location': 'โออาฮู', 'name': 'ไซต์ประวัติศาสตร์และสถาบันเก็บเอกสารบ้านมิชชันนารีฮาวาย', 'rating': 4.5, 'reviews': ['["ทัวร์ที่น่าสนใจและน่าดึงดูดใจ ฉันตั้งใจที่จะทำทัวร์นี้มาเป็นเวลานานและได้วางแผนสำหรับมันในการกลับมาที่โออาฮูที่รอคอยมานานของฉัน\\n\\nในกลุ่มของเรามีเพียงสามคนรวมทั้งไกด์ของเรา ไมค์ ที่เต็มไปด้วยข้อมูลทางประวัติศาสตร์ เขาได้ทำให้วันที่แสนเริ่มต้นมีชีวิตชีวาขึ้นด้วยข้อเท็จจริงและเล่าเรื่องราว ควบคู่กับเรา ไมค์พาเราไปอยู่ในภาพยนตร์ "ฮาวาย" ข้างๆ จูลี่ แอนดรูว์ ในชั่วขณะหนึ่ง\\n\\nคุณจะได้เยี่ยมชมสามอาคาร ซึ่งได้แก่ อาคารดั้งเดิมและเก่าแก่ที่สุดในโฮโนลูลู บ้านมิชชันนารีแห่งที่สอง และร้านพิมพ์ที่น่าทึ่งซึ่งเป็นที่ที่ภาษาเฮาชันถูกบันทึกลงบนกระดาษเป็นครั้งแรก\\n\\nร้านของขวัญเต็มไปด้วยงานฝีมือของชาวฮาวายและหนังสือดีๆ มากมาย คุณสามารถนั่งในลานภายในที่ร่มรื่นและคิดคำนึงถึงอดีต แม้ว่าจะถูกล้อมรอบด้วยอาคารสมัยใหม่ในใจกลางโฮโนลูลู ไก่ที่เป็นมิตรบ้างก็อาจมาเป็นเพื่อนคุณได้ด้วย\\n\\nหมายเหตุหนึ่งข้อ คุณจะต้องขึ้นและลงบันไดบางแห่ง ดังนั้นโปรดระมัดระวังในเรื่องนี้ เดินทางคนเดียว", "ทัวร์สำหรับคนรักประวัติศาสตร์ที่น่าทึ่ง นี่คือสถานที่ที่ห้ามพลาด ให้แน่ใจว่าคุณได้จองออนไลน์ล่วงหน้าก่อน\\n\\nเราทำทัวร์สำหรับคนรักประวัติศาสตร์ที่นำโดยไมค์ สมูล่า และมันยอดเยี่ยมมาก -- ไมค์มีความรู้ลึกซึ้งและมีพลังใจ รวมทั้งคิดไตร่ตรองอย่างรอบคอบและมีความหลงใหล เขาสับเปลี่ยนระหว่างการลงลึกในหัวข้อที่เรามีคำถามและการให้ภาพรวมกว้างๆ เกี่ยวกับประวัติศาสตร์ฮาวายและบทบาทของมิชชันในนั้นได้อย่างราบรื่น มันหายากที่จะเรียนรู้มากมายในเวลาอันสั้นจากครูที่กระตือรือร้นเช่นนี้\\n\\nสมาชิกคนหนึ่งในกลุ่มของเราคือประวัติศาสตร์มืออาชีพและเขาก็สนุกกับมันไม่น้อยไปกว่าที่เราเป็นคนทั่วไป", "การเยี่ยมชมที่คุ้มค่าเหมาะสำหรับทุกวัย นี่คือการเยี่ยมชมที่ให้ความรู้และสนุกสนาน หมู่บ้านผู้ดูแลของเราน่าทึ่ง ตอบคำถามมากมาย เรามีกรุ๊ปเล็กๆ ซึ่งดีมาก เราชอบสถาปัตยกรรมภายในของอาคารและได้สัมผัสถึงชีวิตและการทำงานของมิชชันนารีในเมื่อ 200 ปีที่แล้ว มันเป็นการเยี่ยมชมที่ยอดเยี่ยม ควรชมคู่กับพระราชวังอิโออานิ ซึ่งจะช่วยเชื่อมโยงเรื่องราวให้สมบูรณ์ จองล่วงหน้าจะช่วยได้มาก", "เดินทางเป็นคู่"]'], 'url': 'https://www.tripadvisor.com/Attraction_Review-g60982-d117382-Reviews-Hawaiian_Mission_Houses_Historic_Site_and_Archives-Honolulu_Oahu_Hawaii.html'}
# page_content='{'categories': array(['พิพิธภัณฑ์เฉพาะทาง', 'พิพิธภัณฑ์ประวัติศาสตร์'], dtype=object), 'description': 'ตั้งอยู่ใจกลางเขตการเงินของซานฟรานซิสโก พิพิธภัณฑ์นี้แสดงให้เห็นถึงบทบาทสำคัญของเวลส์ ฟาร์โกในช่วงการค้นพบทองคำในแคลิฟอร์เนีย ประวัติศาสตร์ของซานฟรานซิสโก การเดินทางด้วยเกวียนในแคลิฟอร์เนียยุคแรก และการตั้งถิ่นฐานของชาวอเมริกันตะวันตก ผู้เยี่ยมชมทุกวัยสามารถเพลิดเพลินกับนิทรรศการเชิงโต้ตอบที่สนุกสนาน รวมถึง "ประสบการณ์นั่งรถเกวียน" เครื่องธนาคารโบราณที่ใช้งานได้ โทรเลขที่ทำงาน วิดีโอ และวัตถุโบราณที่แท้จริงเช่น รถเกวียนต้นฉบับจากปี 1868 เหรียญประวัติศาสตร์ สกุลเงิน แผนที่ และภาพถ่าย ร้านค้าที่พิพิธภัณฑ์มีของขวัญของสะสม และเสื้อผ้าที่มีแบรนด์เวลส์ ฟาร์โก หทาเปิดการทัวร์นำชมพร้อมการจองล่วงหน้า และการเข้าชมพิพิธภัณฑ์นั้นฟรีเสมอ.'}' metadata={'location': 'ซานฟรานซิสโก', 'name': 'พิพิธภัณฑ์เวลส์ ฟาร์โก', 'rating': 4.5, 'reviews': ['["พิพิธภัณฑ์เชิงโต้ตอบที่ยอดเยี่ยม, พิพิธภัณฑ์ที่ยอดเยี่ยมจริงๆ มีการโต้ตอบและให้ข้อมูลที่ดี คุณสามารถพิมพ์หน้าของคุณลงบนเงินหรือขี่รถม้า Wells Fargo หรือทดลองรหัสมอร์ส! มันยอดเยี่ยมมาก และได้เรียนรู้เกี่ยวกับ Wells Fargo อย่างมาก, เดินทางเป็นคู่", "รถม้า, Pony Express, การขุดทอง, การธนาคาร และอื่นๆ: พิพิธภัณฑ์ Wells Fargo, ซานฟรานซิสโก, ฉันไปที่พิพิธภัณฑ์ Wells Fargo ในซานฟรานซิสโก มันเล่าเรื่องราวของนักธนาคารสองคน คือคุณ Wells และคุณ Fargo ธนาคารนี้ตั้งชื่อตามพวกเขาว่า Wells Fargo\\n\\nมีนิทรรศการสนุก ๆ ที่จัดแสดงเกี่ยวกับรถม้า, การขุดทอง, การธนาคาร, Pony Express และอื่นๆ มีกรุ๊ปนักเรียนที่มาเรียนรู้เกี่ยวกับประวัติศาสตร์ที่นั่นด้วย\\n\\nมีนิทรรศการตั้งอยู่สองชั้น\\n\\nการเข้าชมฟรี", "สนใจมาก! , เราได้เดินทางด้วยรถ RV ไปทั่วสหรัฐอเมริกา แวะไปยังเมืองที่เกี่ยวข้องกับการขุดทองหลายแห่งในระหว่างการเดินทาง นี่คือพิพิธภัณฑ์ขนาดเล็ก แต่เป็นกุญแจสำคัญในเส้นทางของเรา! นี่คือจุดเริ่มต้นทั้งหมด เราพบว่าพิพิธภัณฑ์นี้น่าสนใจมากและชื่นชอบแนวคิดเชิงโต้ตอบสำหรับทุกสิ่ง! ขอแนะนำอย่างยิ่ง ชอบเครื่องถ่ายเอกสารยุคแรก...ไม่ได้ทำสิ่งที่ไม่เหมาะสมนั้นแน่นอน! , เดินทางเป็นคู่"]'], 'url': 'https://www.tripadvisor.com/Attraction_Review-g60713-d145245-Reviews-Wells_Fargo_Museum-San_Francisco_California.html'}
# page_content='{'categories': array(['สถานที่น่าสนใจและแลนด์มาร์ก'], dtype=object), 'description': 'ภูมิภาคตอนเหนือของโออาฮูเป็นจุดหมายปลายทางที่มีความน่าสนใจในตัวเอง นำเสนอสิ่งมหัศจรรย์ทางธรรมชาติและกิจกรรมในรีสอร์ทที่หลากหลาย.'}' metadata={'location': 'โออาฮู', 'name': 'North Shore แปลว่า "ชายฝั่งเหนือ"', 'rating': 4.5, 'reviews': ['["มิตรภาพและความเป็นมืออาชีพที่ยอดเยี่ยมของ Tiho, ทัวร์ North Shore ตลอดทั้งวันวันนี้ โดยมี Tiho เป็นไกด์และคนขับนั้นครบถ้วน ตรงเวลา และโดยรวมสนุกสนานและจัดได้ดีมาก Tiho ให้ข้อมูลที่น่าสนใจเกี่ยวกับประวัติศาสตร์และข้อเท็จจริงของฮาวายมากมาย ขณะที่เขานำเราไปยังจุดท่องเที่ยวต่างๆ รอบเกาะโออาฮู ฉันขอแนะนำทัวร์นี้ให้กับผู้ที่เพิ่งมาถึงโออาฮู เพราะทัวร์นี้จะให้คุณได้เห็นและสัมผัสกับหลายสิ่งที่น่าทึ่งที่นี่, เดินทางกับครอบครัว", "จำเป็นต้องใช้วันเพิ่มเติม, สำหรับผู้ที่ไม่ได้เดินทางในฐานะนักท่องเที่ยวที่โฮโนลูลูเพียง 3 ถึง 4 วัน, ควรใช้เวลาอีกหนึ่งวันเพื่อไปเที่ยว North Shore เพื่อสัมผัสกับบรรยากาศที่แตกต่างออกไปจากความวุ่นวายของเมือง\\n\\nเมื่อเราออกจากเมือง เราจะเห็นแนวชายฝั่ง คลื่นสูงที่เหมาะสำหรับโต้คลื่น นักโต้คลื่น และผู้ที่ไปชายหาด\\n\\nไปจนถึง Haleiwa เพื่อสำรวจเมืองเล็กๆ แห่งนี้ ซึ่งแตกต่างจากโฮโนลูลูอย่างแน่นอน\\n\\nรถประจำทาง 65 จาก Ala Moana Center ไปถึง Haleiwa และเราสามารถหยุดที่ชายหาดที่มีชื่อเสียงตามทางได้ ", "อโลฮ่า! สิ่งที่ฉันชอบทำที่สุด คือการเช่ารถและหนีจากไวคีกิ มันเป็นการขับขี่ที่ยอดเยี่ยม และมีหลายสถานที่ที่น่าสนใจให้เยี่ยมชมระหว่างทาง นาวแมนของคุณจะต้องการให้คุณใช้ทางด่วน แต่ขอแนะนำให้ลองขับตามแนวชายฝั่งอย่างน้อยสักครั้ง มันเป็นการขับขี่ที่สวยงาม ค้นหาใน Google ว่า \'แผนการท่องเที่ยวทริปวัน North Shore\' คุณจะพบวันดีๆ ที่วางแผนไว้สำหรับคุณ อย่าลืมรถขายอาหาร!", เดินทางในฐานะคู่รัก]'], 'url': 'https://www.tripadvisor.com/Attraction_Review-g29222-d207512-Reviews-North_Shore-Oahu_Hawaii.html'}

# %%
queries = [
    "อยากไปเที่ยวพิพิธภัณฑ์ในไมอามี่",
    "สถานที่เกี่ยวกับศิลปะและวัฒนธรรม" ,
    "อยากดูภาพจิตรกรรมฝาผนังหรือกราฟฟิตี้",
    "มีที่ไหนที่จัดแสดงผลงานศิลปะบ้าง",
    "อยากได้สถานที่ท่องเที่ยวที่เป็นมรดกทางวัฒนธรรม",
    "อยากเที่ยวกับครอบครัว",
    "สถานที่ที่เหมาะกับการพักผ่อน",
    "อยากไปถ่ายรูปสวยๆ",
    "สถานที่มีกิจกรรมสนุกๆ ให้ทำ",
    "อยากไปที่เหมาะกับเด็กๆ",
    "สถานที่ที่มีทั้งพิพิธภัณฑ์และสวนสวย",
    "อยากไปที่ที่มีสัตว์และสามารถเรียนรู้ได้ด้วย",
    "อยากเที่ยวแบบไม่ใช่ในตัวเมือง",
    "อยากได้ที่เที่ยวที่มีทั้งศิลปะและธรรมชาติ",
    "สถานที่ที่สามารถเรียนรู้ประวัติศาสตร์ของไมอามี่"
]
for q in queries:
    print(q)
    v = vectorstore.similarity_search_with_score(q,k=5)
    for i,score in v:
        page = str(i.page_content)
        if "array([" in page:
            try:
                cat_part = page.split("array([")[1].split("],")[0]
            except Exception:
                cat_part = "-"
        else:
            cat_part = "-"
        # print(i)
        print(f"- Place : {i.metadata.get('name','?')}")
        print(f"    - Score    : {score:.5f}")
        print(f"    - Category : {cat_part}")
        print(f"    - Position : {i.metadata.get('location','?')}")
        print(f"    - url      : {i.metadata.get('url','?')}")

    print()
# Out:
# อยากไปเที่ยวพิพิธภัณฑ์ในไมอามี่
# - Place : North End ภาษาไทยคือ "ตอนเหนือ"
#     - Score    : 160.59131
#     - Category : 'ย่าน'
#     - Position : บอสตัน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60745-d103113-Reviews-North_End-Boston_Massachusetts.html
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 157.13037
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : สวนพฤกษศาสตร์ปล่องภูเขาไฟโคโค่
#     - Score    : 154.10645
#     - Category : 'สวน'
#     - Position : โอะอาฮู
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60982-d560888-Reviews-Koko_Crater_Botanical_Garden-Honolulu_Oahu_Hawaii.html
# - Place : พีระมิดทรานซาเมอริกา
#     - Score    : 153.61426
#     - Category : 'สถานที่น่าสนใจและสถานที่สำคัญ', 'อาคารสถาปัตยกรรม'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d144408-Reviews-Transamerica_Pyramid-San_Francisco_California.html
# - Place : ศูนย์ประชุมห้องสมุดฮาร์โรลด์ วอชิงตัน
#     - Score    : 153.44824
#     - Category : 'ห้องสมุด'
#     - Position : ชิคาโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g35805-d110079-Reviews-Harold_Washington_Library_Center-Chicago_Illinois.html
#
# สถานที่เกี่ยวกับศิลปะและวัฒนธรรม
# - Place : Escape Hunt แปลเป็นภาษาไทยว่า "การล่าหาในการหลบหนี"
#     - Score    : 167.70508
#     - Category : 'เกมหลบหนี'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d13977197-Reviews-Escape_Hunt-Miami_Florida.html
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 166.86914
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : อัลตาพลาซ่า พาร์ค
#     - Score    : 164.53809
#     - Category : 'สวนสาธารณะ', 'สวน'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d7733962-Reviews-Alta_Plaza_Park-San_Francisco_California.html
# - Place : Brickell City Center переводится на тайский как: บริคเคลซิตี้เซ็นเตอร์
#     - Score    : 164.03809
#     - Category : 'ศูนย์การค้า'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d11923181-Reviews-Brickell_City_Center-Miami_Florida.html
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 163.80371
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
#
# อยากดูภาพจิตรกรรมฝาผนังหรือกราฟฟิตี้
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 193.55566
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 192.15332
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : Escape Hunt แปลเป็นภาษาไทยว่า "การล่าหาในการหลบหนี"
#     - Score    : 188.92676
#     - Category : 'เกมหลบหนี'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d13977197-Reviews-Escape_Hunt-Miami_Florida.html
# - Place : Brickell City Center переводится на тайский как: บริคเคลซิตี้เซ็นเตอร์
#     - Score    : 187.90430
#     - Category : 'ศูนย์การค้า'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d11923181-Reviews-Brickell_City_Center-Miami_Florida.html
# - Place : พิพิธภัณฑ์เวลส์ ฟาร์โก
#     - Score    : 187.77441
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง', 'พิพิธภัณฑ์ประวัติศาสตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d145245-Reviews-Wells_Fargo_Museum-San_Francisco_California.html
#
# มีที่ไหนที่จัดแสดงผลงานศิลปะบ้าง
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 136.17578
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : ศูนย์ประชุมห้องสมุดฮาร์โรลด์ วอชิงตัน
#     - Score    : 130.25879
#     - Category : 'ห้องสมุด'
#     - Position : ชิคาโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g35805-d110079-Reviews-Harold_Washington_Library_Center-Chicago_Illinois.html
# - Place : ศูนย์ฟอร์ตเมสัน
#     - Score    : 127.67090
#     - Category : 'ท่าเรือ', 'พิพิธภัณฑ์ศิลปะ'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d311683-Reviews-Fort_Mason_Center-San_Francisco_California.html
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 126.35156
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : พิพิธภัณฑ์เวลส์ ฟาร์โก
#     - Score    : 121.02441
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง', 'พิพิธภัณฑ์ประวัติศาสตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d145245-Reviews-Wells_Fargo_Museum-San_Francisco_California.html
#
# อยากได้สถานที่ท่องเที่ยวที่เป็นมรดกทางวัฒนธรรม
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 194.52539
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 192.43164
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : พิพิธภัณฑ์เวลส์ ฟาร์โก
#     - Score    : 190.88867
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง', 'พิพิธภัณฑ์ประวัติศาสตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d145245-Reviews-Wells_Fargo_Museum-San_Francisco_California.html
# - Place : Escape Hunt แปลเป็นภาษาไทยว่า "การล่าหาในการหลบหนี"
#     - Score    : 190.47266
#     - Category : 'เกมหลบหนี'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d13977197-Reviews-Escape_Hunt-Miami_Florida.html
# - Place : Brickell City Center переводится на тайский как: บริคเคลซิตี้เซ็นเตอร์
#     - Score    : 188.71387
#     - Category : 'ศูนย์การค้า'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d11923181-Reviews-Brickell_City_Center-Miami_Florida.html
#
# อยากเที่ยวกับครอบครัว
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 62.87891
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : อัลตาพลาซ่า พาร์ค
#     - Score    : 58.15918
#     - Category : 'สวนสาธารณะ', 'สวน'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d7733962-Reviews-Alta_Plaza_Park-San_Francisco_California.html
# - Place : ไซต์ประวัติศาสตร์และสถาบันเก็บเอกสารบ้านมิชชันนารีฮาวาย
#     - Score    : 51.50391
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง'
#     - Position : โออาฮู
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60982-d117382-Reviews-Hawaiian_Mission_Houses_Historic_Site_and_Archives-Honolulu_Oahu_Hawaii.html
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 50.19043
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : North End ภาษาไทยคือ "ตอนเหนือ"
#     - Score    : 48.76660
#     - Category : 'ย่าน'
#     - Position : บอสตัน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60745-d103113-Reviews-North_End-Boston_Massachusetts.html
#
# สถานที่ที่เหมาะกับการพักผ่อน
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 75.21582
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : อัลตาพลาซ่า พาร์ค
#     - Score    : 67.52441
#     - Category : 'สวนสาธารณะ', 'สวน'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d7733962-Reviews-Alta_Plaza_Park-San_Francisco_California.html
# - Place : ไซต์ประวัติศาสตร์และสถาบันเก็บเอกสารบ้านมิชชันนารีฮาวาย
#     - Score    : 61.58594
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง'
#     - Position : โออาฮู
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60982-d117382-Reviews-Hawaiian_Mission_Houses_Historic_Site_and_Archives-Honolulu_Oahu_Hawaii.html
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 60.95410
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : สถานที่จัดแสดงละครคาดิลแลค ปาเลซ
#     - Score    : 59.74463
#     - Category : 'โรงละคร'
#     - Position : ชิคาโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g35805-d4131440-Reviews-Cadillac_Palace_Theatre-Chicago_Illinois.html
#
# อยากไปถ่ายรูปสวยๆ
# - Place : Escape Hunt แปลเป็นภาษาไทยว่า "การล่าหาในการหลบหนี"
#     - Score    : 152.76953
#     - Category : 'เกมหลบหนี'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d13977197-Reviews-Escape_Hunt-Miami_Florida.html
# - Place : อัลตาพลาซ่า พาร์ค
#     - Score    : 148.71729
#     - Category : 'สวนสาธารณะ', 'สวน'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d7733962-Reviews-Alta_Plaza_Park-San_Francisco_California.html
# - Place : อควาเรียมของอ่าว
#     - Score    : 146.23145
#     - Category : 'พิพิธภัณฑ์สัตว์น้ำ'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d527436-Reviews-Aquarium_of_the_Bay-San_Francisco_California.html
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 145.93018
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : แสงสว่างในเมือง
#     - Score    : 145.71680
#     - Category : 'จุดสนใจและแลนด์มาร์ก'
#     - Position : ลอสแองเจลิส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g32655-d12903209-Reviews-Urban_Light-Los_Angeles_California.html
#
# สถานที่มีกิจกรรมสนุกๆ ให้ทำ
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 104.94824
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : ไซต์ประวัติศาสตร์และสถาบันเก็บเอกสารบ้านมิชชันนารีฮาวาย
#     - Score    : 104.45410
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง'
#     - Position : โออาฮู
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60982-d117382-Reviews-Hawaiian_Mission_Houses_Historic_Site_and_Archives-Honolulu_Oahu_Hawaii.html
# - Place : พิพิธภัณฑ์เวลส์ ฟาร์โก
#     - Score    : 103.73926
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง', 'พิพิธภัณฑ์ประวัติศาสตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d145245-Reviews-Wells_Fargo_Museum-San_Francisco_California.html
# - Place : อัลตาพลาซ่า พาร์ค
#     - Score    : 97.76758
#     - Category : 'สวนสาธารณะ', 'สวน'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d7733962-Reviews-Alta_Plaza_Park-San_Francisco_California.html
# - Place : แสงสว่างในเมือง
#     - Score    : 97.72070
#     - Category : 'จุดสนใจและแลนด์มาร์ก'
#     - Position : ลอสแองเจลิส
#     - url      : https://www.tripadvisor.com/Attraction_Review-g32655-d12903209-Reviews-Urban_Light-Los_Angeles_California.html
#
# อยากไปที่เหมาะกับเด็กๆ
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 168.84473
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : Escape Hunt แปลเป็นภาษาไทยว่า "การล่าหาในการหลบหนี"
#     - Score    : 166.91846
#     - Category : 'เกมหลบหนี'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d13977197-Reviews-Escape_Hunt-Miami_Florida.html
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 166.64453
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : Brickell City Center переводится на тайский как: บริคเคลซิตี้เซ็นเตอร์
#     - Score    : 165.28760
#     - Category : 'ศูนย์การค้า'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d11923181-Reviews-Brickell_City_Center-Miami_Florida.html
# - Place : อัลตาพลาซ่า พาร์ค
#     - Score    : 163.79297
#     - Category : 'สวนสาธารณะ', 'สวน'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d7733962-Reviews-Alta_Plaza_Park-San_Francisco_California.html
#
# สถานที่ที่มีทั้งพิพิธภัณฑ์และสวนสวย
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 80.65576
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 72.47266
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : อัลตาพลาซ่า พาร์ค
#     - Score    : 72.36279
#     - Category : 'สวนสาธารณะ', 'สวน'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d7733962-Reviews-Alta_Plaza_Park-San_Francisco_California.html
# - Place : ไซต์ประวัติศาสตร์และสถาบันเก็บเอกสารบ้านมิชชันนารีฮาวาย
#     - Score    : 70.18750
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง'
#     - Position : โออาฮู
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60982-d117382-Reviews-Hawaiian_Mission_Houses_Historic_Site_and_Archives-Honolulu_Oahu_Hawaii.html
# - Place : North End ภาษาไทยคือ "ตอนเหนือ"
#     - Score    : 68.79834
#     - Category : 'ย่าน'
#     - Position : บอสตัน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60745-d103113-Reviews-North_End-Boston_Massachusetts.html
#
# อยากไปที่ที่มีสัตว์และสามารถเรียนรู้ได้ด้วย
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 193.96094
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 191.98047
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : Escape Hunt แปลเป็นภาษาไทยว่า "การล่าหาในการหลบหนี"
#     - Score    : 189.61816
#     - Category : 'เกมหลบหนี'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d13977197-Reviews-Escape_Hunt-Miami_Florida.html
# - Place : พิพิธภัณฑ์เวลส์ ฟาร์โก
#     - Score    : 189.08105
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง', 'พิพิธภัณฑ์ประวัติศาสตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d145245-Reviews-Wells_Fargo_Museum-San_Francisco_California.html
# - Place : Brickell City Center переводится на тайский как: บริคเคลซิตี้เซ็นเตอร์
#     - Score    : 187.53906
#     - Category : 'ศูนย์การค้า'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d11923181-Reviews-Brickell_City_Center-Miami_Florida.html
#
# อยากเที่ยวแบบไม่ใช่ในตัวเมือง
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 164.41113
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : Escape Hunt แปลเป็นภาษาไทยว่า "การล่าหาในการหลบหนี"
#     - Score    : 163.82471
#     - Category : 'เกมหลบหนี'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d13977197-Reviews-Escape_Hunt-Miami_Florida.html
# - Place : Brickell City Center переводится на тайский как: บริคเคลซิตี้เซ็นเตอร์
#     - Score    : 162.50049
#     - Category : 'ศูนย์การค้า'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d11923181-Reviews-Brickell_City_Center-Miami_Florida.html
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 161.73975
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : พิพิธภัณฑ์เวลส์ ฟาร์โก
#     - Score    : 161.02100
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง', 'พิพิธภัณฑ์ประวัติศาสตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d145245-Reviews-Wells_Fargo_Museum-San_Francisco_California.html
#
# อยากได้ที่เที่ยวที่มีทั้งศิลปะและธรรมชาติ
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 194.20215
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 191.48047
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : Escape Hunt แปลเป็นภาษาไทยว่า "การล่าหาในการหลบหนี"
#     - Score    : 189.67773
#     - Category : 'เกมหลบหนี'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d13977197-Reviews-Escape_Hunt-Miami_Florida.html
# - Place : พิพิธภัณฑ์เวลส์ ฟาร์โก
#     - Score    : 189.54492
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง', 'พิพิธภัณฑ์ประวัติศาสตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d145245-Reviews-Wells_Fargo_Museum-San_Francisco_California.html
# - Place : Brickell City Center переводится на тайский как: บริคเคลซิตี้เซ็นเตอร์
#     - Score    : 187.71289
#     - Category : 'ศูนย์การค้า'
#     - Position : ไมอามี่
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d11923181-Reviews-Brickell_City_Center-Miami_Florida.html
#
# สถานที่ที่สามารถเรียนรู้ประวัติศาสตร์ของไมอามี่
# - Place : ไซต์ประวัติศาสตร์และสถาบันเก็บเอกสารบ้านมิชชันนารีฮาวาย
#     - Score    : 160.22852
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง'
#     - Position : โออาฮู
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60982-d117382-Reviews-Hawaiian_Mission_Houses_Historic_Site_and_Archives-Honolulu_Oahu_Hawaii.html
# - Place : เสรีภาพทาวเวอร์ที่วิทยาลัยไมอามีเดด
#     - Score    : 153.53223
#     - Category : 'สถานที่ประวัติศาสตร์', 'อาคารสถาปัตยกรรม'
#     - Position : ไมอามี
#     - url      : https://www.tripadvisor.com/Attraction_Review-g34438-d532100-Reviews-Freedom_Tower_at_Miami_Dade_College-Miami_Florida.html
# - Place : อาสนวิหารเซนต์แมรี่
#     - Score    : 152.47754
#     - Category : 'อาคารสถาปัตยกรรม', 'สถานที่ทางศาสนา'
#     - Position : ออสติน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g30196-d560357-Reviews-St_Mary_s_Cathedral-Austin_Texas.html
# - Place : North End ภาษาไทยคือ "ตอนเหนือ"
#     - Score    : 151.59277
#     - Category : 'ย่าน'
#     - Position : บอสตัน
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60745-d103113-Reviews-North_End-Boston_Massachusetts.html
# - Place : พิพิธภัณฑ์เวลส์ ฟาร์โก
#     - Score    : 146.69336
#     - Category : 'พิพิธภัณฑ์เฉพาะทาง', 'พิพิธภัณฑ์ประวัติศาสตร์'
#     - Position : ซานฟรานซิสโก
#     - url      : https://www.tripadvisor.com/Attraction_Review-g60713-d145245-Reviews-Wells_Fargo_Museum-San_Francisco_California.html
