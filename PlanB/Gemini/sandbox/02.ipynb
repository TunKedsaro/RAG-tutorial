# %% [raw]
# ### Anatomy of prompt
# - 01. Role
# - 02. Objective
# - 03. Section-Specific Expectations
# - 04. Criteria definitions [Completeness, Content Quality, Grammar&Language, Length/Amount, Role relevance]
# - 05. Scoring Guideline
# - 06. Output format
# - 07. Input

# %% [raw]
# # 01 Role
# You are a senior career evaluator and resume expert specializing in data-related
#
# # 02 Objective
# Evaluate the <section_name> section from the resume using the scoring criteria
#
# # 03 Section-Specific Expectations
# You are evaluating the <section_name> section.
#
# # 04 Expected content
# <SECTION_GUIDELINES>
#
# # 05 Evaluation Criteria
# - Completeness: ...
# - ContentQuality: ...
# - Grammar: ...
# - Length: ...
# - RoleRelevance: ...
#
# # 06 Scoring Scale
# 0 = missing
# 1 = poor
# 2 = weak
# 3 = sufficient
# 4 = strong
# 5 = excellent
#
# # 07 Output format
# {
#     "section": "<section_name>",
#     "scores": {
#         "<criterion>": {
#             "score": <0-5>,
#             "feedback": "<short reason>"
#             }
#         }
#     }
#
# # 08 Input
# {input_cv}

# %%
# Prompt1 : Profile
prompt1 = prompt_builder.build( 
    section  = "Experience", 
    criteria = ["Completeness", "ContentQuality"],
    input_cv = resume_json 
)

# %%
# Prompt2 : Summary
prompt2 = prompt_builder.build( 
    section  = "Summary", 
    criteria = ["Completeness", "ContentQuality", "Grammar", "Length", "RoleRelevance"],
    input_cv = resume_json 
)

# %%
# Prompt3 : Education
prompt3 = prompt_builder.build( 
    section  = "Education", 
    criteria = ["Completeness", "RoleRelevance"],
    input_cv = resume_json 
)

# %%
# Prompt4 : Experience
prompt4 = prompt_builder.build( 
    section  = "Experience", 
    criteria = ["Completeness", "ContentQuality", "Grammar", "Length", "RoleRelevance"],
    input_cv = resume_json 
)

# %%
# Prompt5 : Activities
prompt5 = prompt_builder.build( 
    section  = "Activities", 
    criteria = ["Completeness", "ContentQuality", "Grammar", "Length"],
    input_cv = resume_json 
)

# %%
# Prompt6 : Skills
prompt6 = prompt_builder.build( 
    section  = "Skills", 
    criteria = ["Completeness", "Length", "RoleRelevance"],
    input_cv = resume_json 
)

# %% [markdown]
# <hr>

# %% [raw]
# # # Prompt1 - Profile
# # 01 Role
# You are a senior career evaluator and resume expert specializing in data-related careers.
#
# # 02 Objective
# Evaluate the Profile section from the resume using the scoring criteria.
#
# # 03 Section-Specific Expectations
# You are evaluating the Profile section.
#
# # 04 Expected content
# - Candidate's basic personal/professional identity
# - High-level positioning (e.g., “Data Analyst”, “ML Engineer”)
# - Clear statement of career direction
# - No unnecessary personal details
#
# # 05 Evaluation Criteria
# - Completeness: Is basic profile information present and relevant?
# - ContentQuality: Is the description meaningful and aligned with a data-related career?
#
# # 06 Scoring Scale
# 0 = missing
# 1 = poor
# 2 = weak
# 3 = sufficient
# 4 = strong
# 5 = excellent
#
# # 07 Output Format
# {
#   "section": "Profile",
#   "scores": {
#     "<criterion>": {
#       "score": <0-5>,
#       "feedback": "<short reason>"
#     }
#   }
# }
#
# # 08 Input
# {input_cv}

# %% [raw]
# # # Prompt2 - Summary
# # 01 Role
# You are a senior career evaluator and resume expert specializing in data-related careers.
#
# # 02 Objective
# Evaluate the Profile section from the resume using the scoring criteria.
#
# # 03 Section-Specific Expectations
# You are evaluating the Profile section.
#
# # 04 Expected content
# - Candidate's basic personal/professional identity
# - High-level positioning (e.g., “Data Analyst”, “ML Engineer”)
# - Clear statement of career direction
# - No unnecessary personal details
#
# # 05 Evaluation Criteria
# - Completeness: Is basic profile information present and relevant?
# - ContentQuality: Is the description meaningful and aligned with a data-related career?
#
# # 06 Scoring Scale
# 0 = missing
# 1 = poor
# 2 = weak
# 3 = sufficient
# 4 = strong
# 5 = excellent
#
# # 07 Output Format
# {
#   "section": "Profile",
#   "scores": {
#     "<criterion>": {
#       "score": <0-5>,
#       "feedback": "<short reason>"
#     }
#   }
# }
#
# # 08 Input
# {input_cv}

# %% [raw]
# # # Prompt3 - Education
# # 01 Role
# You are a senior career evaluator and resume expert specializing in data-related careers.
#
# # 02 Objective
# Evaluate the Summary section from the resume using the scoring criteria.
#
# # 03 Section-Specific Expectations
# You are evaluating the Summary section.
#
# # 04 Expected content
# - 2–4 sentence summary of experience
# - Key technical and domain strengths
# - Career focus and value proposition
# - Avoid buzzwords and irrelevant statements
#
# # 05 Evaluation Criteria
# - Completeness
# - ContentQuality
# - Grammar
# - Length
# - RoleRelevance
#
# # 06 Scoring Scale
# 0 = missing
# 1 = poor
# 2 = weak
# 3 = sufficient
# 4 = strong
# 5 = excellent
#
# # 07 Output Format
# {
#   "section": "Summary",
#   "scores": {
#     "<criterion>": {
#       "score": <0-5>,
#       "feedback": "<short reason>"
#     }
#   }
# }
#
# # 08 Input
# {input_cv}

# %% [raw]
# # # Prompt4 - Experience
# # 01 Role
# You are a senior career evaluator and resume expert specializing in data-related careers.
#
# # 02 Objective
# Evaluate the Experience section from the resume using the scoring criteria.
#
# # 03 Section-Specific Expectations
# You are evaluating the Experience section.
#
# # 04 Expected content
# - Job title, employer, and dates
# - Bullet points describing responsibilities and achievements
# - Use of action → method → impact structure
# - Quantifiable metrics when possible
# - Tools, techniques, and technologies used
#
# # 05 Evaluation Criteria
# - Completeness
# - ContentQuality
# - Grammar
# - Length
# - RoleRelevance
#
# # 06 Scoring Scale
# 0 = missing
# 1 = poor
# 2 = weak
# 3 = sufficient
# 4 = strong
# 5 = excellent
#
# # 07 Output Format
# {
#   "section": "Experience",
#   "scores": {
#     "<criterion>": {
#       "score": <0-5>,
#       "feedback": "<short reason>"
#     }
#   }
# }
#
# # 08 Input
# {input_cv}

# %% [raw]
# # # Prompt5 - Activities
#
# # 01 Role
# You are a senior career evaluator and resume expert specializing in data-related careers.
#
# # 02 Objective
# Evaluate the Activities / Projects section using the scoring criteria.
#
# # 03 Section-Specific Expectations
# You are evaluating the Activities section.
#
# # 04 Expected content
# - University activities, competitions, hackathons
# - Personal or academic projects
# - Clear description of responsibilities or outcomes
# - Mention of tools, frameworks, or technologies if applicable
#
# # 05 Evaluation Criteria
# - Completeness
# - ContentQuality
# - Grammar
# - Length
#
# # 06 Scoring Scale
# 0 = missing
# 1 = poor
# 2 = weak
# 3 = sufficient
# 4 = strong
# 5 = excellent
#
# # 07 Output Format
# {
#   "section": "Activities",
#   "scores": {
#     "<criterion>": {
#       "score": <0-5>,
#       "feedback": "<short reason>"
#     }
#   }
# }
#
# # 08 Input
# {input_cv}

# %% [raw]
# # # Prompt6 - Skills
# # 01 Role
# You are a senior career evaluator and resume expert specializing in data-related careers.
#
# # 02 Objective
# Evaluate the Skills section using the scoring criteria.
#
# # 03 Section-Specific Expectations
# You are evaluating the Skills section.
#
# # 04 Expected content
# - Technical skills (Python, SQL, ML, Cloud)
# - Tools (Power BI, TensorFlow, Git)
# - Soft skills (communication, teamwork)
# - Languages
# - Grouped or categorized clearly
#
# # 05 Evaluation Criteria
# - Completeness
# - Length
# - RoleRelevance
#
# # 06 Scoring Scale
# 0 = missing
# 1 = poor
# 2 = weak
# 3 = sufficient
# 4 = strong
# 5 = excellent
#
# # 07 Output Format
# {
#   "section": "Skills",
#   "scores": {
#     "<criterion>": {
#       "score": <0-5>,
#       "feedback": "<short reason>"
#     }
#   }
# }
#
# # 08 Input
# {input_cv}

# %% [markdown]
# <hr>

# %%
import yaml
import os

# %%
class PromptBuilder:
    def __init__(self,section,criteria):
        self.section  = section
        self.criteria = criteria
        with open("role.yaml","r",encoding="utf-8") as f:
            self.role = yaml.safe_load(f)
        with open("objective.yaml","r",encoding="utf-8") as f:
            self.obj = yaml.safe_load(f)        
        with open("section.yaml","r",encoding="utf-8") as f:
            self.sect = yaml.safe_load(f)        
        with open("Expected.yaml","r",encoding="utf-8") as f:
            self.expt = yaml.safe_load(f)        
        with open("scale.yaml","r",encoding="utf-8") as f:
            self.scal = yaml.safe_load(f)        
        with open("output.yaml","r",encoding="utf-8") as f:
            self.outp = yaml.safe_load(f)
        print(self.scal)

    def build(self):
        print(self.section)
        print(self.criteria)
        print(self.role)
        role = self.role['role']['role1']
        ojb  = self.obj['obj']['object']
        sect = self.sect['section']['section']
        expt = self.expt['expected_content'][self.section]
        self.prompt_criteria = ""
        for item in self.criteria:
            self.prompt_criteria = f"- {item}\n" + self.prompt_criteria
        scal = self.scal['scale']['scoring_scale']
        outp = self.outp['output']['default']
        # prompt
        prompt_role = f"Role :\n{role}"+"\n"
        prompt_obj  = f"objectvie :\n{ojb}"+"\n"
        prompt_sect  = f"section :\n{sect}"+"\n"
        prompt_expt  = f"section :\n{expt}"+"\n"
        prompt_crit  = f"Criteria :\n{self.prompt_criteria}"+"\n"
        prompt_scal  = f"Scale :\n{scal}"+"\n"
        prompt_outp  = f"output :\n{outp}"+"\n"

        prompt = prompt_role + prompt_obj + prompt_sect + prompt_expt + \
            prompt_crit + prompt_scal + prompt_outp
        # prompt = prompt.replace("<section_name>",self.section)
        print(prompt)

# %%
p = PromptBuilder(
    section = "Summary",
    criteria = ["Completeness", "ContentQuality"]
)
p.build()
# Out:
# {'scale': {'scoring_scale': '0 = missing\n1 = poor\n2 = weak\n3 = sufficient\n4 = strong\n5 = excellent'}}
# Summary
# ['Completeness', 'ContentQuality']
# {'role': {'role1': 'You are the senior data science'}}
# Role :
# You are the senior data science
# objectvie :
# Evaluate the <section_name> section from the resume using the scoring criteria
# section :
# You are evaluating the <section_name> section.
# section :
# - 2-4 sentence summary of experience
# - Technical & domain strengths
# - Career focus & value proposition
# - Avoid buzzwords
# Criteria :
# - ContentQuality
# - Completeness
#
# Scale :
# 0 = missing
# 1 = poor
# 2 = weak
# 3 = sufficient
# 4 = strong
# 5 = excellent
# output :
# {
#   "Score":0,
#   "Feedback":"xxx"
# }
